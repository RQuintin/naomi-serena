# %% [markdown]
# # Data Analysis
#
# In this notebook, I'd like to finally get down to analyzing the sentiment of these tweets. We'll need to conduct the analysis, store the result in a new column of the dataframe, and then visualize it somehow to get an understanding of what's going on. Let's get started!
#
# **Hypothesis:** Tweets about Naomi Osaka will be overwhelmingly more positive than tweets about Serena Williams.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd

from statistics import mean
from textblob import TextBlob

# %%
filepath = "./data/CLEANED_naomi-serena.pkl"

# %%
data = pd.read_pickle(filepath)

# %%
data.head()
# Out:
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query
# 0  [naomi, osaka, upset, serena, williams, contro...  naomi osaka
# 1              [go, girl, got, back, congrats, open]  naomi osaka
# 2  [probably, felt, like, friend, house, mom, sta...  naomi osaka
# 3  [congrats, girly, let, anyone, take, moment, o...  naomi osaka
# 4  [naomi, osaka, defeat, serena, williams, drama...  naomi osaka

# %%
test_data = data[:10].copy()
test_data
# Out:
#                         tweet_date  \
# 0   Sat Sep 08 19:59:59 +0000 2018
# 1   Sat Sep 08 19:59:57 +0000 2018
# 2   Sat Sep 08 19:59:56 +0000 2018
# 3   Sat Sep 08 19:59:55 +0000 2018
# 4   Sat Sep 08 19:59:55 +0000 2018
# 6   Sat Sep 08 19:59:54 +0000 2018
# 7   Sat Sep 08 19:59:52 +0000 2018
# 8   Sat Sep 08 19:59:50 +0000 2018
# 9   Sat Sep 08 19:59:50 +0000 2018
# 10  Sat Sep 08 19:59:49 +0000 2018
#
#                                            tweet_text search query
# 0   [naomi, osaka, upset, serena, williams, contro...  naomi osaka
# 1               [go, girl, got, back, congrats, open]  naomi osaka
# 2   [probably, felt, like, friend, house, mom, sta...  naomi osaka
# 3   [congrats, girly, let, anyone, take, moment, o...  naomi osaka
# 4   [naomi, osaka, defeat, serena, williams, drama...  naomi osaka
# 6   [carlos, ramos, also, robbed, osaka, imagine, ...  naomi osaka
# 7   [yes, bravo, bajin, course, love, always, sinc...  naomi osaka
# 8   [tennis, official, coach, seen, coaching, play...  naomi osaka
# 9   [naomi, osaka, top, serena, williams, open, fi...  naomi osaka
# 10  [booing, damn, naomi, osaka, girl, cooking, go...  naomi osaka

# %%
for tweet in test_data['tweet_text']:
    for word in tweet:
        print(TextBlob(word).sentiment)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.55, subjectivity=0.95)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.4333333333333333, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.2, subjectivity=0.2)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.4, subjectivity=0.4)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.6)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.1, subjectivity=0.1)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.5)
# Sentiment(polarity=0.0, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.25, subjectivity=0.3333333333333333)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.5, subjectivity=1.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=-0.07142857142857142, subjectivity=0.21428571428571427)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.7, subjectivity=0.6000000000000001)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.4, subjectivity=0.7)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)

# %% [markdown]
# This is pretty interesting. It looks like most words are neutral and don't mean anything. What I'd like to do is two analyses of sentiment:
#
# 1. Get the sentiment of each word, average them to get the total sentiment of those words
# 2. Combine the words into a pseudo-sentence and get the average sentiment of the sentence

# %% [markdown]
# ## Strategy 1: Word-Based Sentiment

# %%
def get_sentiment(tweets):
    
    for tweet in tweets:
        sentiments = []
        for word in tweet:
            sentiments.append(TextBlob(word).sentiment.polarity)
        return mean(sentiments)

# %%
get_sentiment(test_data['tweet_text'])
# Out:
# 0.05500000000000001

# %% [markdown]
# In analyzing this output, I'm not sure I like what I'm seeing. Tweets that are clearly positive in nature are registering as neutral, and tweets that couldn't be considered negative have a score above zero. Let's see if the sentence-based method has any different output.

# %%
def get_sentiment_2(tweets):
    
    for tweet in tweets:
        sentiments = []
        sentence = " ".join(tweet)
        print(sentence, TextBlob(sentence).sentiment.polarity)

# %%
get_sentiment_2(test_data['tweet_text'])
# Out:
# naomi osaka upset serena williams controversial open final cnn smartnews 0.18333333333333335
# go girl got back congrats open 0.0
# probably felt like friend house mom started yelling usopen 0.0
# congrats girly let anyone take moment outplayed everyone even goat serena 0.0
# naomi osaka defeat serena williams dramatic open final -0.14444444444444443
# carlos ramos also robbed osaka imagine much better would feel broke serena go instead giving game 0.04999999999999999
# yes bravo bajin course love always since turned pro 0.5
# tennis official coach seen coaching player issue warning coach called ejected better yet get rid coaching signal rule altogether player helpless effect coach action mid match 0.19999999999999998
# naomi osaka top serena williams open final becomes first japanese grand slam single champion japan time 0.1683673469387755
# booing damn naomi osaka girl cooking good job spot light earned naomi 0.55

# %% [markdown]
# A bit better, but I'm starting to think that it was a mistake tokenizing the words the way I did. Let's see if I can perform the sentiment on these tweets with no tokenization.

# %%
test_file = pd.read_pickle("./data/DATA00_naomi-serena-all.pkl")

# %%
test_file.head()
# Out:
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query
# 0  Naomi Osaka upsets Serena Williams in controve...  naomi osaka
# 1  @ Naomi_Osaka_ , you go girl! I got your back!...  naomi osaka
# 2  @ Naomi_Osaka_ probably felt like she was at h...  naomi osaka
# 3  Congrats girly, don’t let anyone take this mom...  naomi osaka
# 4  Naomi Osaka defeats Serena Williams in a drama...  naomi osaka

# %%
test2 = test_file[:10].copy()

# %%
test2
# Out:
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
# 5  Sat Sep 08 19:59:55 +0000 2018
# 6  Sat Sep 08 19:59:54 +0000 2018
# 7  Sat Sep 08 19:59:52 +0000 2018
# 8  Sat Sep 08 19:59:50 +0000 2018
# 9  Sat Sep 08 19:59:50 +0000 2018
#
#                                           tweet_text search query
# 0  Naomi Osaka upsets Serena Williams in controve...  naomi osaka
# 1  @ Naomi_Osaka_ , you go girl! I got your back!...  naomi osaka
# 2  @ Naomi_Osaka_ probably felt like she was at h...  naomi osaka
# 3  Congrats girly, don’t let anyone take this mom...  naomi osaka
# 4  Naomi Osaka defeats Serena Williams in a drama...  naomi osaka
# 5  https://twitter.com/juventino5555/status/10377...  naomi osaka
# 6  Carlos Ramos also robbed Osaka. Imagine how mu...  naomi osaka
# 7  Yes Bravo to @ BigSascha Bajin And of course l...  naomi osaka
# 8  Tennis officials.. where coaches are seen coac...  naomi osaka
# 9  Naomi Osaka tops Serena Williams in U.S. Open ...  naomi osaka

# %%
for tweet in test2['tweet_text']:
    print(tweet, TextBlob(tweet).sentiment.polarity)
# Out:
# Naomi Osaka upsets Serena Williams in controversial US Open final - CNN # SmartNewshttps://edition.cnn.com/2018/09/08/sport/naomi-osaka-serena-williams-us-open-tennis-int-spt/index.html … 0.18333333333333335
# @ Naomi_Osaka_ , you go girl! I got your back! Congrats on the US open! 0.0
# @ Naomi_Osaka_ probably felt like she was at her friend’s house when their mom started yelling at them # usopen 0.0
# Congrats girly, don’t let anyone take this moment from you..you outplayed everyone, even the GOAT Serena @ Naomi_Osaka_ 0.0
# Naomi Osaka defeats Serena Williams in a dramatic US Open final https://twitter.com/i/events/1038540032330493952 … -0.14444444444444443
# https://twitter.com/juventino5555/status/1037768949109276672?s=19 … 0.0
# Carlos Ramos also robbed Osaka. Imagine how much better she would feel if she broke Serena to go up 5-3 instead of being giving the game. 0.04999999999999999
# Yes Bravo to @ BigSascha Bajin And of course love as always (since she turned pro!) to @ Naomi_Osaka_ https://twitter.com/bgtennisnation/status/1038563742961881090 … 0.625
# Tennis officials.. where coaches are seen coaching their player.. why not issue a warning to the coach.. and if he is called on it again, he is ejected. Better yet.. get rid of the coaching signals rule altogether..A player is helpless to effect their coach’s actions mid match. 0.25
# Naomi Osaka tops Serena Williams in U.S. Open final, becomes first Japanese grand slam singles champion | The Japan Times https://www.japantimes.co.jp/sports/2018/09/09/more-sports/tennis/naomi-osaka-tops-serena-williams-u-s-open-final-becomes-first-japanese-grand-slam-singles-champion/#.W5Ric76cSlQ.twitter … 0.15

# %% [markdown]
# These still seem overwhelmingly positive, though I'm getting more sentiment than from the tokenized corpus alone. Just to test the hypothesis, let's see what happens with the last 10 tweets of the dataset.

# %%
test3 = test_file[-10:].copy()

# %%
test3
# Out:
#                            tweet_date  \
# 23818  Sat Sep 08 18:45:26 +0000 2018
# 23819  Sat Sep 08 18:45:25 +0000 2018
# 23820  Sat Sep 08 18:45:25 +0000 2018
# 23821  Sat Sep 08 18:45:25 +0000 2018
# 23822  Sat Sep 08 18:45:25 +0000 2018
# 23823  Sat Sep 08 18:45:25 +0000 2018
# 23824  Sat Sep 08 18:45:24 +0000 2018
# 23825  Sat Sep 08 18:45:24 +0000 2018
# 23826  Sat Sep 08 18:45:23 +0000 2018
# 23827  Sat Sep 08 18:45:23 +0000 2018
#
#                                               tweet_text     search query
# 23818  You should see what Serena's coach has just ad...  serena williams
# 23819  Serena Williams. The greatest athlete of all t...  serena williams
# 23820  Congrats to # naomiosaka who just won the # US...  serena williams
# 23821  Justified as in being upset at a stupid rule/v...  serena williams
# 23822  That's why you're so irrelevant Mr. Kasich. Ca...  serena williams
# 23823  @ serenawilliams you are an inspiration and a ...  serena williams
# 23824  @ serenawilliams I love you so much mommy. I k...  serena williams
# 23825  @ serenawilliams Mama needs a dictionary. Grac...  serena williams
# 23826        I’d rather lose than cheat @ serenawilliams  serena williams
# 23827  Sorry, don't agree on this one. Referee had no...  serena williams

# %%
for tweet in test3['tweet_text']:
    print(tweet, TextBlob(tweet).sentiment.polarity)
# Out:
# You should see what Serena's coach has just admitted to. Yep, coaching his player. 0.0
# Serena Williams. The greatest athlete of all time. A black woman. # USOpen18 0.4166666666666667
# Congrats to # naomiosaka who just won the # USopen against her idol, # SerenaWilliams https://www.instagram.com/p/Bne3yDrBRn3/?utm_source=ig_twitter_share&igshid=755i1rx1ff4k … 0.0
# Justified as in being upset at a stupid rule/violation. -0.19999999999999996
# That's why you're so irrelevant Mr. Kasich. Calling an umpire names and a thief is not being a real sport and a class act. -0.15
# @ serenawilliams you are an inspiration and a role model for women. Not only in sports but ALL women. # UsOpenFinal 0.0
# @ serenawilliams I love you so much mommy. I know that you were right. You are amazing woman and I want to be like you. I will never ever stop dreaming to see you. And of course congratulations @ Naomi_Osaka_. Don't be sad. You are amazing. You don't deserve that, but life happenspic.twitter.com/PMWFTayrqH 0.280952380952381
# @ serenawilliams Mama needs a dictionary. Gracious? Humble? Ummm, OK. And remember, what you think is right is just your opinion. 0.1952380952380952
# I’d rather lose than cheat @ serenawilliams 0.0
# Sorry, don't agree on this one. Referee had no business making a baseless accusation and taking a point. It was unjust & wrong. It set @ serenawilliams off & they knew it would. This will take away from Osaka's win. An idiot referee wanting to be the star. -0.25

# %% [markdown]
# Still not quite what I was expecting, but the sentiment is there, nonetheless.
#
# Let's do a side-by-side comparison of them both, with just the tokenized sentences.

# %%
test_data['lexicon-based sentiment'] = test_data['tweet_text'].apply(lambda x: mean([TextBlob(word).sentiment.polarity for word in x]))

# %%
test_data
# Out:
#                         tweet_date  \
# 0   Sat Sep 08 19:59:59 +0000 2018
# 1   Sat Sep 08 19:59:57 +0000 2018
# 2   Sat Sep 08 19:59:56 +0000 2018
# 3   Sat Sep 08 19:59:55 +0000 2018
# 4   Sat Sep 08 19:59:55 +0000 2018
# 6   Sat Sep 08 19:59:54 +0000 2018
# 7   Sat Sep 08 19:59:52 +0000 2018
# 8   Sat Sep 08 19:59:50 +0000 2018
# 9   Sat Sep 08 19:59:50 +0000 2018
# 10  Sat Sep 08 19:59:49 +0000 2018
#
#                                            tweet_text search query  \
# 0   [naomi, osaka, upset, serena, williams, contro...  naomi osaka
# 1               [go, girl, got, back, congrats, open]  naomi osaka
# 2   [probably, felt, like, friend, house, mom, sta...  naomi osaka
# 3   [congrats, girly, let, anyone, take, moment, o...  naomi osaka
# 4   [naomi, osaka, defeat, serena, williams, drama...  naomi osaka
# 6   [carlos, ramos, also, robbed, osaka, imagine, ...  naomi osaka
# 7   [yes, bravo, bajin, course, love, always, sinc...  naomi osaka
# 8   [tennis, official, coach, seen, coaching, play...  naomi osaka
# 9   [naomi, osaka, top, serena, williams, open, fi...  naomi osaka
# 10  [booing, damn, naomi, osaka, girl, cooking, go...  naomi osaka
#
#     lexicon-based sentiment
# 0                  0.055000
# 1                  0.000000
# 2                  0.000000
# 3                  0.000000
# 4                 -0.054167
# 6                  0.018750
# 7                  0.055556
# 8                  0.023077
# 9                  0.073661
# 10                 0.091667

# %%
test_data['pseudo-sentence sentiment'] = test_data['tweet_text'].apply(lambda x: TextBlob(" ".join(x)).sentiment.polarity)

# %%
test_data
# Out:
#                         tweet_date  \
# 0   Sat Sep 08 19:59:59 +0000 2018
# 1   Sat Sep 08 19:59:57 +0000 2018
# 2   Sat Sep 08 19:59:56 +0000 2018
# 3   Sat Sep 08 19:59:55 +0000 2018
# 4   Sat Sep 08 19:59:55 +0000 2018
# 6   Sat Sep 08 19:59:54 +0000 2018
# 7   Sat Sep 08 19:59:52 +0000 2018
# 8   Sat Sep 08 19:59:50 +0000 2018
# 9   Sat Sep 08 19:59:50 +0000 2018
# 10  Sat Sep 08 19:59:49 +0000 2018
#
#                                            tweet_text search query  \
# 0   [naomi, osaka, upset, serena, williams, contro...  naomi osaka
# 1               [go, girl, got, back, congrats, open]  naomi osaka
# 2   [probably, felt, like, friend, house, mom, sta...  naomi osaka
# 3   [congrats, girly, let, anyone, take, moment, o...  naomi osaka
# 4   [naomi, osaka, defeat, serena, williams, drama...  naomi osaka
# 6   [carlos, ramos, also, robbed, osaka, imagine, ...  naomi osaka
# 7   [yes, bravo, bajin, course, love, always, sinc...  naomi osaka
# 8   [tennis, official, coach, seen, coaching, play...  naomi osaka
# 9   [naomi, osaka, top, serena, williams, open, fi...  naomi osaka
# 10  [booing, damn, naomi, osaka, girl, cooking, go...  naomi osaka
#
#     lexicon-based sentiment  pseudo-sentence sentiment
# 0                  0.055000                   0.183333
# 1                  0.000000                   0.000000
# 2                  0.000000                   0.000000
# 3                  0.000000                   0.000000
# 4                 -0.054167                  -0.144444
# 6                  0.018750                   0.050000
# 7                  0.055556                   0.500000
# 8                  0.023077                   0.200000
# 9                  0.073661                   0.168367
# 10                 0.091667                   0.550000

# %% [markdown]
# It looks like the pseudo-sentence sentiment is stronger, with a significant difference in polarity. I think it might be beneficial to retain a tokenized and non-tokenized version of the tweet, to compare those sentiment polarities as well.

# %%
# %run scrub_tweets.py
# Out:
# Filename: DATA00_naomi-serena-all.pkl
# Loading ./data/DATA00_naomi-serena-all.pkl...
# A brief look at the data...
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query
# 0  Naomi Osaka upsets Serena Williams in controve...  naomi osaka
# 1  @ Naomi_Osaka_ , you go girl! I got your back!...  naomi osaka
# 2  @ Naomi_Osaka_ probably felt like she was at h...  naomi osaka
# 3  Congrats girly, don’t let anyone take this mom...  naomi osaka
# 4  Naomi Osaka defeats Serena Williams in a drama...  naomi osaka
# ---------------------------
#                            tweet_date  \
# 23823  Sat Sep 08 18:45:25 +0000 2018
# 23824  Sat Sep 08 18:45:24 +0000 2018
# 23825  Sat Sep 08 18:45:24 +0000 2018
# 23826  Sat Sep 08 18:45:23 +0000 2018
# 23827  Sat Sep 08 18:45:23 +0000 2018
#
#                                               tweet_text     search query
# 23823  @ serenawilliams you are an inspiration and a ...  serena williams
# 23824  @ serenawilliams I love you so much mommy. I k...  serena williams
# 23825  @ serenawilliams Mama needs a dictionary. Grac...  serena williams
# 23826        I’d rather lose than cheat @ serenawilliams  serena williams
# 23827  Sorry, don't agree on this one. Referee had no...  serena williams
# Step 1: Removing noise...
# Done.
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query
# 0  Naomi Osaka upsets Serena Williams in controve...  naomi osaka
# 1    , you go girl! I got your back! Congrats on ...  naomi osaka
# 2    probably felt like she was at her friend’s h...  naomi osaka
# 3  Congrats girly, don’t let anyone take this mom...  naomi osaka
# 4  Naomi Osaka defeats Serena Williams in a drama...  naomi osaka
# Step 2: Normalizing text...
# Done.
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query
# 0  naomi osaka upsets serena williams in controve...  naomi osaka
# 1      you go girl  i got your back  congrats on ...  naomi osaka
# 2    probably felt like she was at her friends ho...  naomi osaka
# 3  congrats girly  do not let anyone take this mo...  naomi osaka
# 4  naomi osaka defeats serena williams in a drama...  naomi osaka
# Step 3: Preprocessing text...
# Done.
# Your cleaned data:
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query  \
# 0  naomi osaka upsets serena williams in controve...  naomi osaka
# 1      you go girl  i got your back  congrats on ...  naomi osaka
# 2    probably felt like she was at her friends ho...  naomi osaka
# 3  congrats girly  do not let anyone take this mo...  naomi osaka
# 4  naomi osaka defeats serena williams in a drama...  naomi osaka
#
#                                      processed_tweet
# 0  [naomi, osaka, upset, serena, williams, contro...
# 1              [go, girl, got, back, congrats, open]
# 2  [probably, felt, like, friend, house, mom, sta...
# 3  [congrats, girly, let, anyone, take, moment, o...
# 4  [naomi, osaka, defeat, serena, williams, drama...
# ---------------------------
#                            tweet_date  \
# 23823  Sat Sep 08 18:45:25 +0000 2018
# 23824  Sat Sep 08 18:45:24 +0000 2018
# 23825  Sat Sep 08 18:45:24 +0000 2018
# 23826  Sat Sep 08 18:45:23 +0000 2018
# 23827  Sat Sep 08 18:45:23 +0000 2018
#
#                                               tweet_text     search query  \
# 23823    you are an inspiration and a role model for ...  serena williams
# 23824    i love you so much mommy  i know that you we...  serena williams
# 23825    mama needs a dictionary  gracious  humble  u...  serena williams
# 23826                   i would rather lose than cheat    serena williams
# 23827  sorry  do not agree on this one  referee had n...  serena williams
#
#                                          processed_tweet
# 23823  [inspiration, role, model, woman, sport, woman...
# 23824  [love, much, mommy, know, right, amazing, woma...
# 23825  [mama, need, dictionary, gracious, humble, umm...
# 23826                       [would, rather, lose, cheat]
# 23827  [sorry, agree, one, referee, business, making,...
# Save file as: DATA02_naomi-serena-processed.pkl
# Saving ./data/CLEANED_DATA02_naomi-serena-processed.pkl...
# Done. End.

# %%
new_data = pd.read_pickle("./data/CLEANED_DATA02_naomi-serena-processed.pkl")

# %%
new_data.head()
# Out:
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query  \
# 0  naomi osaka upsets serena williams in controve...  naomi osaka
# 1      you go girl  i got your back  congrats on ...  naomi osaka
# 2    probably felt like she was at her friends ho...  naomi osaka
# 3  congrats girly  do not let anyone take this mo...  naomi osaka
# 4  naomi osaka defeats serena williams in a drama...  naomi osaka
#
#                                      processed_tweet
# 0  [naomi, osaka, upset, serena, williams, contro...
# 1              [go, girl, got, back, congrats, open]
# 2  [probably, felt, like, friend, house, mom, sta...
# 3  [congrats, girly, let, anyone, take, moment, o...
# 4  [naomi, osaka, defeat, serena, williams, drama...

# %%
new_test_data = new_data[:10].copy()

# %%
new_test_data['tweet sentiment'] = new_test_data['tweet_text'].apply(lambda x: TextBlob(x).sentiment.polarity)
new_test_data['tokenized sentiment'] = new_test_data['processed_tweet'].apply(lambda x: mean([TextBlob(word).sentiment.polarity for word in x]))

# %%
new_test_data
# Out:
#                         tweet_date  \
# 0   Sat Sep 08 19:59:59 +0000 2018
# 1   Sat Sep 08 19:59:57 +0000 2018
# 2   Sat Sep 08 19:59:56 +0000 2018
# 3   Sat Sep 08 19:59:55 +0000 2018
# 4   Sat Sep 08 19:59:55 +0000 2018
# 6   Sat Sep 08 19:59:54 +0000 2018
# 7   Sat Sep 08 19:59:52 +0000 2018
# 8   Sat Sep 08 19:59:50 +0000 2018
# 9   Sat Sep 08 19:59:50 +0000 2018
# 10  Sat Sep 08 19:59:49 +0000 2018
#
#                                            tweet_text search query  \
# 0   naomi osaka upsets serena williams in controve...  naomi osaka
# 1       you go girl  i got your back  congrats on ...  naomi osaka
# 2     probably felt like she was at her friends ho...  naomi osaka
# 3   congrats girly  do not let anyone take this mo...  naomi osaka
# 4   naomi osaka defeats serena williams in a drama...  naomi osaka
# 6   carlos ramos also robbed osaka  imagine how mu...  naomi osaka
# 7   yes bravo to   bajin and of course love as alw...  naomi osaka
# 8   tennis officials   where coaches are seen coac...  naomi osaka
# 9   naomi osaka tops serena williams in u s  open ...  naomi osaka
# 10  booing damn naomi osaka won the girl was cooki...  naomi osaka
#
#                                       processed_tweet  tweet sentiment  \
# 0   [naomi, osaka, upset, serena, williams, contro...         0.183333
# 1               [go, girl, got, back, congrats, open]         0.000000
# 2   [probably, felt, like, friend, house, mom, sta...         0.000000
# 3   [congrats, girly, let, anyone, take, moment, o...         0.000000
# 4   [naomi, osaka, defeat, serena, williams, drama...        -0.144444
# 6   [carlos, ramos, also, robbed, osaka, imagine, ...         0.050000
# 7   [yes, bravo, bajin, course, love, always, sinc...         0.500000
# 8   [tennis, official, coach, seen, coaching, play...         0.250000
# 9   [naomi, osaka, top, serena, williams, open, fi...         0.150000
# 10  [booing, damn, naomi, osaka, girl, cooking, go...         0.550000
#
#     tokenized sentiment
# 0              0.055000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4             -0.054167
# 6              0.018750
# 7              0.055556
# 8              0.023077
# 9              0.073661
# 10             0.091667

# %%
new_test_data.rename(index=str, columns={"tweet_text": "original tweet", "processed_tweet": "tweet_text"})
# Out:
#                         tweet_date  \
# 0   Sat Sep 08 19:59:59 +0000 2018
# 1   Sat Sep 08 19:59:57 +0000 2018
# 2   Sat Sep 08 19:59:56 +0000 2018
# 3   Sat Sep 08 19:59:55 +0000 2018
# 4   Sat Sep 08 19:59:55 +0000 2018
# 6   Sat Sep 08 19:59:54 +0000 2018
# 7   Sat Sep 08 19:59:52 +0000 2018
# 8   Sat Sep 08 19:59:50 +0000 2018
# 9   Sat Sep 08 19:59:50 +0000 2018
# 10  Sat Sep 08 19:59:49 +0000 2018
#
#                                        original tweet search query  \
# 0   naomi osaka upsets serena williams in controve...  naomi osaka
# 1       you go girl  i got your back  congrats on ...  naomi osaka
# 2     probably felt like she was at her friends ho...  naomi osaka
# 3   congrats girly  do not let anyone take this mo...  naomi osaka
# 4   naomi osaka defeats serena williams in a drama...  naomi osaka
# 6   carlos ramos also robbed osaka  imagine how mu...  naomi osaka
# 7   yes bravo to   bajin and of course love as alw...  naomi osaka
# 8   tennis officials   where coaches are seen coac...  naomi osaka
# 9   naomi osaka tops serena williams in u s  open ...  naomi osaka
# 10  booing damn naomi osaka won the girl was cooki...  naomi osaka
#
#                                            tweet_text  tweet sentiment  \
# 0   [naomi, osaka, upset, serena, williams, contro...         0.183333
# 1               [go, girl, got, back, congrats, open]         0.000000
# 2   [probably, felt, like, friend, house, mom, sta...         0.000000
# 3   [congrats, girly, let, anyone, take, moment, o...         0.000000
# 4   [naomi, osaka, defeat, serena, williams, drama...        -0.144444
# 6   [carlos, ramos, also, robbed, osaka, imagine, ...         0.050000
# 7   [yes, bravo, bajin, course, love, always, sinc...         0.500000
# 8   [tennis, official, coach, seen, coaching, play...         0.250000
# 9   [naomi, osaka, top, serena, williams, open, fi...         0.150000
# 10  [booing, damn, naomi, osaka, girl, cooking, go...         0.550000
#
#     tokenized sentiment
# 0              0.055000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4             -0.054167
# 6              0.018750
# 7              0.055556
# 8              0.023077
# 9              0.073661
# 10             0.091667

# %%
earlier_results = test_data[["lexicon-based sentiment", "pseudo-sentence sentiment"]]

# %%
new_test_data.join(earlier_results)
# Out:
#                         tweet_date  \
# 0   Sat Sep 08 19:59:59 +0000 2018
# 1   Sat Sep 08 19:59:57 +0000 2018
# 2   Sat Sep 08 19:59:56 +0000 2018
# 3   Sat Sep 08 19:59:55 +0000 2018
# 4   Sat Sep 08 19:59:55 +0000 2018
# 6   Sat Sep 08 19:59:54 +0000 2018
# 7   Sat Sep 08 19:59:52 +0000 2018
# 8   Sat Sep 08 19:59:50 +0000 2018
# 9   Sat Sep 08 19:59:50 +0000 2018
# 10  Sat Sep 08 19:59:49 +0000 2018
#
#                                            tweet_text search query  \
# 0   naomi osaka upsets serena williams in controve...  naomi osaka
# 1       you go girl  i got your back  congrats on ...  naomi osaka
# 2     probably felt like she was at her friends ho...  naomi osaka
# 3   congrats girly  do not let anyone take this mo...  naomi osaka
# 4   naomi osaka defeats serena williams in a drama...  naomi osaka
# 6   carlos ramos also robbed osaka  imagine how mu...  naomi osaka
# 7   yes bravo to   bajin and of course love as alw...  naomi osaka
# 8   tennis officials   where coaches are seen coac...  naomi osaka
# 9   naomi osaka tops serena williams in u s  open ...  naomi osaka
# 10  booing damn naomi osaka won the girl was cooki...  naomi osaka
#
#                                       processed_tweet  tweet sentiment  \
# 0   [naomi, osaka, upset, serena, williams, contro...         0.183333
# 1               [go, girl, got, back, congrats, open]         0.000000
# 2   [probably, felt, like, friend, house, mom, sta...         0.000000
# 3   [congrats, girly, let, anyone, take, moment, o...         0.000000
# 4   [naomi, osaka, defeat, serena, williams, drama...        -0.144444
# 6   [carlos, ramos, also, robbed, osaka, imagine, ...         0.050000
# 7   [yes, bravo, bajin, course, love, always, sinc...         0.500000
# 8   [tennis, official, coach, seen, coaching, play...         0.250000
# 9   [naomi, osaka, top, serena, williams, open, fi...         0.150000
# 10  [booing, damn, naomi, osaka, girl, cooking, go...         0.550000
#
#     tokenized sentiment  lexicon-based sentiment  pseudo-sentence sentiment
# 0              0.055000                 0.055000                   0.183333
# 1              0.000000                 0.000000                   0.000000
# 2              0.000000                 0.000000                   0.000000
# 3              0.000000                 0.000000                   0.000000
# 4             -0.054167                -0.054167                  -0.144444
# 6              0.018750                 0.018750                   0.050000
# 7              0.055556                 0.055556                   0.500000
# 8              0.023077                 0.023077                   0.200000
# 9              0.073661                 0.073661                   0.168367
# 10             0.091667                 0.091667                   0.550000

# %% [markdown]
# The results are almost exactly the same: a pseudo-sentence made by concatenating the tokenized words produced much the same sentiment as the tweet itself. Indeed, removing stop words and the like seems to have no impact on the overall sentiment of the tweet. However, analyzing the sentiment by averaging the tokenized words individually seems much less useful than analyzing the sentence as a whole (I believe due to the nature of syntax and semantics on a sentence vs. word level).
#
# Analysis will proceed as follows: by joining the tokenized words into a longer string, and calculating the overall sentiment of the entire phrase.

# %% [markdown]
# ### Calculating Sentiment for Data:

# %%
new_data.head()
# Out:
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query  \
# 0  naomi osaka upsets serena williams in controve...  naomi osaka
# 1      you go girl  i got your back  congrats on ...  naomi osaka
# 2    probably felt like she was at her friends ho...  naomi osaka
# 3  congrats girly  do not let anyone take this mo...  naomi osaka
# 4  naomi osaka defeats serena williams in a drama...  naomi osaka
#
#                                      processed_tweet
# 0  [naomi, osaka, upset, serena, williams, contro...
# 1              [go, girl, got, back, congrats, open]
# 2  [probably, felt, like, friend, house, mom, sta...
# 3  [congrats, girly, let, anyone, take, moment, o...
# 4  [naomi, osaka, defeat, serena, williams, drama...

# %%
analyzed_tweets = new_data.copy()

# %%
analyzed_tweets.head()
# Out:
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query  \
# 0  naomi osaka upsets serena williams in controve...  naomi osaka
# 1      you go girl  i got your back  congrats on ...  naomi osaka
# 2    probably felt like she was at her friends ho...  naomi osaka
# 3  congrats girly  do not let anyone take this mo...  naomi osaka
# 4  naomi osaka defeats serena williams in a drama...  naomi osaka
#
#                                      processed_tweet
# 0  [naomi, osaka, upset, serena, williams, contro...
# 1              [go, girl, got, back, congrats, open]
# 2  [probably, felt, like, friend, house, mom, sta...
# 3  [congrats, girly, let, anyone, take, moment, o...
# 4  [naomi, osaka, defeat, serena, williams, drama...

# %%
analyzed_tweets.tail()
# Out:
#                            tweet_date  \
# 23823  Sat Sep 08 18:45:25 +0000 2018
# 23824  Sat Sep 08 18:45:24 +0000 2018
# 23825  Sat Sep 08 18:45:24 +0000 2018
# 23826  Sat Sep 08 18:45:23 +0000 2018
# 23827  Sat Sep 08 18:45:23 +0000 2018
#
#                                               tweet_text     search query  \
# 23823    you are an inspiration and a role model for ...  serena williams
# 23824    i love you so much mommy  i know that you we...  serena williams
# 23825    mama needs a dictionary  gracious  humble  u...  serena williams
# 23826                   i would rather lose than cheat    serena williams
# 23827  sorry  do not agree on this one  referee had n...  serena williams
#
#                                          processed_tweet
# 23823  [inspiration, role, model, woman, sport, woman...
# 23824  [love, much, mommy, know, right, amazing, woma...
# 23825  [mama, need, dictionary, gracious, humble, umm...
# 23826                       [would, rather, lose, cheat]
# 23827  [sorry, agree, one, referee, business, making,...

# %%
analyzed_tweets['sentiment'] = analyzed_tweets['processed_tweet'].apply(lambda x: TextBlob(" ".join(x)).sentiment.polarity)

# %%
analyzed_tweets.head()
# Out:
#                        tweet_date  \
# 0  Sat Sep 08 19:59:59 +0000 2018
# 1  Sat Sep 08 19:59:57 +0000 2018
# 2  Sat Sep 08 19:59:56 +0000 2018
# 3  Sat Sep 08 19:59:55 +0000 2018
# 4  Sat Sep 08 19:59:55 +0000 2018
#
#                                           tweet_text search query  \
# 0  naomi osaka upsets serena williams in controve...  naomi osaka
# 1      you go girl  i got your back  congrats on ...  naomi osaka
# 2    probably felt like she was at her friends ho...  naomi osaka
# 3  congrats girly  do not let anyone take this mo...  naomi osaka
# 4  naomi osaka defeats serena williams in a drama...  naomi osaka
#
#                                      processed_tweet  sentiment
# 0  [naomi, osaka, upset, serena, williams, contro...   0.183333
# 1              [go, girl, got, back, congrats, open]   0.000000
# 2  [probably, felt, like, friend, house, mom, sta...   0.000000
# 3  [congrats, girly, let, anyone, take, moment, o...   0.000000
# 4  [naomi, osaka, defeat, serena, williams, drama...  -0.144444

# %%
analyzed_tweets.tail()
# Out:
#                            tweet_date  \
# 23823  Sat Sep 08 18:45:25 +0000 2018
# 23824  Sat Sep 08 18:45:24 +0000 2018
# 23825  Sat Sep 08 18:45:24 +0000 2018
# 23826  Sat Sep 08 18:45:23 +0000 2018
# 23827  Sat Sep 08 18:45:23 +0000 2018
#
#                                               tweet_text     search query  \
# 23823    you are an inspiration and a role model for ...  serena williams
# 23824    i love you so much mommy  i know that you we...  serena williams
# 23825    mama needs a dictionary  gracious  humble  u...  serena williams
# 23826                   i would rather lose than cheat    serena williams
# 23827  sorry  do not agree on this one  referee had n...  serena williams
#
#                                          processed_tweet  sentiment
# 23823  [inspiration, role, model, woman, sport, woman...   0.000000
# 23824  [love, much, mommy, know, right, amazing, woma...   0.280952
# 23825  [mama, need, dictionary, gracious, humble, umm...   0.195238
# 23826                       [would, rather, lose, cheat]   0.000000
# 23827  [sorry, agree, one, referee, business, making,...  -0.250000

# %%
analyzed_tweets.sort_values(by="sentiment")
# Out:
#                            tweet_date  \
# 9067   Sat Sep 08 18:35:26 +0000 2018
# 16528  Sat Sep 08 19:22:34 +0000 2018
# 12414  Sat Sep 08 19:52:02 +0000 2018
# 4634   Sat Sep 08 19:07:53 +0000 2018
# 23102  Sat Sep 08 18:48:28 +0000 2018
# 21940  Sat Sep 08 18:53:42 +0000 2018
# 19423  Sat Sep 08 19:05:31 +0000 2018
# 16726  Sat Sep 08 19:21:12 +0000 2018
# 16767  Sat Sep 08 19:20:56 +0000 2018
# 19549  Sat Sep 08 19:04:56 +0000 2018
# 21872  Sat Sep 08 18:54:01 +0000 2018
# 1274   Sat Sep 08 19:43:26 +0000 2018
# 1280   Sat Sep 08 19:43:23 +0000 2018
# 19293  Sat Sep 08 19:06:12 +0000 2018
# 17300  Sat Sep 08 19:17:43 +0000 2018
# 8347   Sat Sep 08 18:39:59 +0000 2018
# 1302   Sat Sep 08 19:43:06 +0000 2018
# 8343   Sat Sep 08 18:40:00 +0000 2018
# 19289  Sat Sep 08 19:06:14 +0000 2018
# 21822  Sat Sep 08 18:54:13 +0000 2018
# 23609  Sat Sep 08 18:46:19 +0000 2018
# 8479   Sat Sep 08 18:39:06 +0000 2018
# 10162  Sat Sep 08 18:29:50 +0000 2018
# 15729  Sat Sep 08 19:27:49 +0000 2018
# 7041   Sat Sep 08 18:48:36 +0000 2018
# 19776  Sat Sep 08 19:03:41 +0000 2018
# 15856  Sat Sep 08 19:27:01 +0000 2018
# 5087   Sat Sep 08 19:03:41 +0000 2018
# 5072   Sat Sep 08 19:03:50 +0000 2018
# 2581   Sat Sep 08 19:28:29 +0000 2018
# ...                               ...
# 5549   Sat Sep 08 19:00:11 +0000 2018
# 781    Sat Sep 08 19:49:48 +0000 2018
# 16998  Sat Sep 08 19:19:27 +0000 2018
# 5491   Sat Sep 08 19:00:37 +0000 2018
# 10947  Sat Sep 08 18:26:42 +0000 2018
# 19362  Sat Sep 08 19:05:48 +0000 2018
# 21391  Sat Sep 08 18:56:07 +0000 2018
# 19355  Sat Sep 08 19:05:51 +0000 2018
# 16009  Sat Sep 08 19:25:57 +0000 2018
# 4993   Sat Sep 08 19:04:34 +0000 2018
# 8146   Sat Sep 08 18:41:17 +0000 2018
# 18205  Sat Sep 08 19:12:29 +0000 2018
# 10917  Sat Sep 08 18:26:49 +0000 2018
# 13521  Sat Sep 08 19:43:30 +0000 2018
# 14429  Sat Sep 08 19:37:05 +0000 2018
# 9378   Sat Sep 08 18:33:42 +0000 2018
# 16029  Sat Sep 08 19:25:48 +0000 2018
# 22453  Sat Sep 08 18:51:12 +0000 2018
# 23413  Sat Sep 08 18:47:06 +0000 2018
# 20308  Sat Sep 08 19:01:08 +0000 2018
# 10930  Sat Sep 08 18:26:45 +0000 2018
# 6568   Sat Sep 08 18:52:04 +0000 2018
# 4968   Sat Sep 08 19:04:48 +0000 2018
# 7176   Sat Sep 08 18:47:36 +0000 2018
# 10075  Sat Sep 08 18:30:11 +0000 2018
# 5986   Sat Sep 08 18:56:43 +0000 2018
# 22481  Sat Sep 08 18:51:02 +0000 2018
# 14468  Sat Sep 08 19:36:45 +0000 2018
# 6421   Sat Sep 08 18:53:19 +0000 2018
# 21337  Sat Sep 08 18:56:21 +0000 2018
#
#                                               tweet_text     search query  \
# 9067   no   you are terribly disrespectful with shing...      naomi osaka
# 16528  yes after   warning she had the penalty  coach...  serena williams
# 12414  shame that disgraceful official did not show h...  serena williams
# 4634   as opposed to carlos stealing a point   how do...      naomi osaka
# 23102        he will forever be known as a horrible ref   serena williams
# 21940  mate you are quoting incidents from decades ag...  serena williams
# 19423  serena williams conduct tonight was disgusting...  serena williams
# 16726                                              awful  serena williams
# 16767  waoooo so serena is for tennis channel what hi...  serena williams
# 19549  disgusting sportsmanship by  serenawilliams  u...  serena williams
# 21872    embarrassing video   just awfully inaccurate     serena williams
# 1274   terrible ref    is the goat  congrats to   on ...      naomi osaka
# 1280   in the end you where a horrible example to you...      naomi osaka
# 19293  you are thanking her for outrageous sportsmans...  serena williams
# 17300  why are you defending serenas bullying  it was...  serena williams
# 8347   selective call from the ump  sexism at it is w...      naomi osaka
# 1302   the crowd were disgusting   and even serena kn...      naomi osaka
# 8343   she deserved that my friend    her coach just ...      naomi osaka
# 19289  did you watch the match  she was the cause of ...  serena williams
# 21822  so you must have willfully ignored the grace o...  serena williams
# 23609    you are my champion today and always  that c...  serena williams
# 8479                 including serena terrible behaviour      naomi osaka
# 10162  what an awful ending to the womens title match...      naomi osaka
# 15729  yes  because now you can pick and choose what ...  serena williams
# 7041                                 fans were pathetic       naomi osaka
# 19776     was awful and her behavior was out of control   serena williams
# 15856  talk about a pathetic straw man argument  mcen...  serena williams
# 5087      was awful and her behavior was out of control       naomi osaka
# 5072   heard serena in press conference trying to mak...      naomi osaka
# 2581   agreed  that had to be the moment of her life ...      naomi osaka
# ...                                                  ...              ...
# 5549         naomi osaka  you did best  congratulation        naomi osaka
# 781                                    you are the best       naomi osaka
# 16998    is still the worlds greatest living athlete ...  serena williams
# 5491      congrats      sis played an excellent match         naomi osaka
# 10947  yes  seena should have restrained herself and ...      naomi osaka
# 19362  you will always always be named the best    us...  serena williams
# 21391                         serena williams is awesome  serena williams
# 19355                                she is the best      serena williams
# 16009  serena williams is one of the greatest athlete...  serena williams
# 4993   seems  the greatest athlete ever  lost to some...      naomi osaka
# 8146    rt      and   you turn the best lawyers into ...      naomi osaka
# 18205  serena williams is the greatest womans tennis ...  serena williams
# 10917    you are the best  you should admire someone ...      naomi osaka
# 13521                            you are awesome serena   serena williams
# 14429  you are going to want to watch a  best if john...  serena williams
# 9378           naomi osaka  you are awesome       usopen      naomi osaka
# 16029  serena williams still the greatest athlete i h...  serena williams
# 22453  serena williams is the greatest athlete of all...  serena williams
# 23413    will always be greatest tennis athlete in hi...  serena williams
# 20308  yet another reason why serena williams may be ...  serena williams
# 10930  got every decision perfectly correct  man dese...      naomi osaka
# 6568   yes  she was well on her way without the chair...      naomi osaka
# 4968        and they played excellent tennis  usopen          naomi osaka
# 7176                nope  naomi osaka is the best today       naomi osaka
# 10075  this espn interview with naomi osaka is deligh...      naomi osaka
# 5986          this made me cry  naomi played awesome          naomi osaka
# 22481  serena did an excellent job during the presser...  serena williams
# 14468  wish she had been more gracious in losing toda...  serena williams
# 6421   the greatest of all time are graf and navratil...      naomi osaka
# 21337  federer  nadal  murray etc etc etc have all ye...  serena williams
#
#                                          processed_tweet  sentiment
# 9067   [terribly, disrespectful, shingo, kunieda, yui...       -1.0
# 16528  [yes, warning, penalty, coach, raquet, screami...       -1.0
# 12414  [shame, disgraceful, official, show, level, re...       -1.0
# 4634   [opposed, carlos, stealing, point, get, coachi...       -1.0
# 23102                    [forever, known, horrible, ref]       -1.0
# 21940  [mate, quoting, incident, decade, ago, abused,...       -1.0
# 19423  [serena, williams, conduct, tonight, disgustin...       -1.0
# 16726                                            [awful]       -1.0
# 16767  [waoooo, serena, tennis, channel, hillary, cnn...       -1.0
# 19549  [disgusting, sportsmanship, serenawilliams, us...       -1.0
# 21872         [embarrassing, video, awfully, inaccurate]       -1.0
# 1274   [terrible, ref, goat, congrats, well, deserved...       -1.0
# 1280   [end, horrible, example, daughter, congratulat...       -1.0
# 19293              [thanking, outrageous, sportsmanship]       -1.0
# 17300  [defending, serenas, bullying, awful, truly, d...       -1.0
# 8347       [selective, call, ump, sexism, worst, robbed]       -1.0
# 1302   [crowd, disgusting, even, serena, knew, told, ...       -1.0
# 8343   [deserved, friend, coach, said, coaching, must...       -1.0
# 19289  [watch, match, cause, booing, tantrum, disgrac...       -1.0
# 21822  [must, willfully, ignored, grace, serena, comf...       -1.0
# 23609            [champion, today, always, chair, awful]       -1.0
# 8479            [including, serena, terrible, behaviour]       -1.0
# 10162  [awful, ending, woman, title, match, usopen, r...       -1.0
# 15729  [yes, pick, choose, show, people, trying, cove...       -1.0
# 7041                                     [fan, pathetic]       -1.0
# 19776                         [awful, behavior, control]       -1.0
# 15856  [talk, pathetic, straw, man, argument, mcenroe...       -1.0
# 5087                          [awful, behavior, control]       -1.0
# 5072   [heard, serena, press, conference, trying, mak...       -1.0
# 2581    [agreed, moment, life, people, booing, horrible]       -1.0
# ...                                                  ...        ...
# 5549                [naomi, osaka, best, congratulation]        1.0
# 781                                               [best]        1.0
# 16998  [still, world, greatest, living, athlete, one,...        1.0
# 5491            [congrats, si, played, excellent, match]        1.0
# 10947  [yes, seena, restrained, none, would, happened...        1.0
# 19362         [always, always, named, best, usopenfinal]        1.0
# 21391                        [serena, williams, awesome]        1.0
# 19355                                             [best]        1.0
# 16009   [serena, williams, one, greatest, athlete, time]        1.0
# 4993   [seems, greatest, athlete, ever, lost, someone...        1.0
# 8146   [rt, turn, best, lawyer, tennis, zombie, black...        1.0
# 18205  [serena, williams, greatest, woman, tennis, pl...        1.0
# 10917  [best, admire, someone, deserves, today, show,...        1.0
# 13521                                  [awesome, serena]        1.0
# 14429  [going, want, watch, best, john, mcenroe, reel...        1.0
# 9378                     [naomi, osaka, awesome, usopen]        1.0
# 16029  [serena, williams, still, greatest, athlete, s...        1.0
# 22453  [serena, williams, greatest, athlete, time, ba...        1.0
# 23413  [always, greatest, tennis, athlete, history, e...        1.0
# 20308  [yet, another, reason, serena, williams, may, ...        1.0
# 10930  [got, every, decision, perfectly, correct, man...        1.0
# 6568   [yes, well, way, without, chair, feeling, need...        1.0
# 4968                 [played, excellent, tennis, usopen]        1.0
# 7176                   [nope, naomi, osaka, best, today]        1.0
# 10075        [espn, interview, naomi, osaka, delightful]        1.0
# 5986                 [made, cry, naomi, played, awesome]        1.0
# 22481  [serena, excellent, job, presser, also, woman,...        1.0
# 14468  [wish, gracious, losing, today, still, best, e...        1.0
# 6421                 [greatest, time, graf, navratiliva]        1.0
# 21337  [federer, nadal, murray, etc, etc, etc, yelled...        1.0
#
# [23775 rows x 5 columns]

# %%
analyzed_tweets.groupby(by="search query").size()
# Out:
# search query
# naomi osaka        11380
# serena williams    12395
# dtype: int64

# %%
naomi_analysis = analyzed_tweets[analyzed_tweets['search query'] == 'naomi osaka']

# %%
serena_analysis = analyzed_tweets[analyzed_tweets['search query'] == 'serena williams']

# %%
naomi_analysis['sentiment'].sum()
# Out:
# 1897.4450200120045

# %%
serena_analysis['sentiment'].sum()
# Out:
# 1305.5000090534168

# %% [markdown]
# I think I've got my final answer! By performing a crude count of the overall sentiment for each search query, I was able to determine that tweets for the search query 'naomi osaka' were on the whole more positive than tweets with the search query 'serena williams'. I wonder if I can perform a statistical analysis to prove this. I'm excited to move into visualizations so I can see this data more clearly.
